# %%
from getpass import getpass

GITHUB_USERNAME = "Yasir-ansari88"
REPO_NAME = "Real-Time-Industrial-Defect-Detection-System"

token = getpass("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")
repo_url = f"https://{GITHUB_USERNAME}:{token}@github.com/{GITHUB_USERNAME}/{REPO_NAME}.git"

# !git clone -q {repo_url}
# %cd {REPO_NAME}
# !ls

del token, repo_url
# Out:
# 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··········
# /content/Real-Time-Industrial-Defect-Detection-System
# data  models  readme.md  requirements.txt  runs  src  yolo26n.pt  yolov8n.pt

# %%
# !pip install -q ultralytics albumentations
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 37.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 6.3 MB/s eta 0:00:00

# %%
import yaml, os

data_yaml_path = 'data/processed/data.yaml'

classes = ["crazing", "inclusion", "patches", "pitted_surface", "rolled-in_scale", "scratches"]

d = {
    "path": os.path.abspath('data/processed'),
    "train": "images/train",
    "val": "images/val",
    "test": "images/test",
    "nc": len(classes),
    "names": classes,
}

with open(data_yaml_path, 'w') as f:
    yaml.safe_dump(d, f, sort_keys=False)

print(open(data_yaml_path).read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1887/2260761604.py in <cell line: 0>()
#      14 }
#      15
# ---> 16 with open(data_yaml_path, 'w') as f:
#      17     yaml.safe_dump(d, f, sort_keys=False)
#      18
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/processed/data.yaml'

# %%
# !cat data/processed/data.yaml
# Out:
# path: /content/Real-Time-Industrial-Defect-Detection-System/data/processed
# train: images/train
# val: images/val
# test: images/test
# nc: 6
# names:
# - crazing
# - inclusion
# - patches
# - pitted_surface
# - rolled-in_scale
# - scratches

# %%
# !python src/Training/tuning.py --data /content/Real-Time-Industrial-Defect-Detection-System/data/processed/data.yaml --tune-epochs 20
# Out:
# ...
# Training config: baseline -> {'name': 'baseline', 'lr0': 0.01, 'imgsz': 640, 'degrees': 25, 'weight_decay': 0.0005}
# ...
# Ultralytics 8.4.121 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')
resulta = model.train(
    data = 'data/processed/data.yaml',
    epochs = 50,
    imgsz = 640,
    batch = 16,
    degrees = 10,
    project = 'models/runs',
    name = 'yolov8n_neu_final',
    patience = 15,
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.122 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.121 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !python src/error_analysis.py \
    --weight /content/Real-Time-Industrial-Defect-Detection-System/runs/detect/models/runs/yolov8n_neu_final/weights/best.pt \
    --data /content/Real-Time-Industrial-Defect-Detection-System/data/processed/data.yaml
# Out:
# Running model.val() for confusion matrix + standard metrics...
# Ultralytics 8.4.121 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1003.8±426.8 MB/s, size: 17.7 KB)
# val: Scanning /content/Real-Time-Industrial-Defect-Detection-System/data/processed/labels/val.cache... 270 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 270/270 53.9Mit/s 0.0s
# val: /content/Real-Time-Industrial-Defect-Detection-System/data/processed/images/val/crazing_120.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 4.2it/s 4.0s
#                    all        270        613      0.725       0.75      0.681      0.384
#                crazing         40         94      0.487      0.394      0.234     0.0838
# ...

# %%
# !python src/preprocessing/oversample_class.py --data-dir data/processed/ --target-classes crazing --multiplier 3
# Out:
# Found 234 original images containing ['crazing'] (out of 1350 total originals).
# Generating 3 extra augmented copies each (~702 new images)...
# /content/Real-Time-Industrial-Defect-Detection-System/src/preprocessing/oversample_class.py:28: UserWarning: Argument(s) 'var_limit' are not valid for transform GaussNoise
#   A.GaussNoise(var_limit=(10.0, 40.0), p=1.0),
# Oversampling: 100% 234/234 [00:02<00:00, 84.53it/s]
#
# Done. Created 702 oversampled image/label pairs.
# Train set size now: 6102 images.
#
# Re-run training

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolov8n.pt')
results = model.train(
    data = 'data/processed/data.yaml',
    epochs = 50,
    imgsz = 640,
    batch = 16,
    degrees = 10,
    project = 'models/runs',
    name = 'yolov8n_neu_oversampled',
    patience = 15,
)
# Out:
# Ultralytics 8.4.123 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !python src/preprocessing/oversample_class.py \
  --data-dir data/processed --target-classes rolled-in_scale --multiplier 2
# Out:
# Found 220 original images containing ['rolled-in_scale'] (out of 1350 total originals).
# Generating 2 extra augmented copies each (~440 new images)...
# /content/Real-Time-Industrial-Defect-Detection-System/src/preprocessing/oversample_class.py:28: UserWarning: Argument(s) 'var_limit' are not valid for transform GaussNoise
#   A.GaussNoise(var_limit=(10.0, 40.0), p=1.0),
# Oversampling: 100% 220/220 [00:01<00:00, 129.91it/s]
#
# Done. Created 440 oversampled image/label pairs.
# Train set size now: 6542 images.
#
# Re-run training

# %%
# !echo 'Train images now :' && ls data/processed/images/train | wc -l
# Out:
# Train images now :
# 6542

# %%
model = YOLO('yolov8n.pt')
results = model.train(
    data = 'data/processed/data.yaml',
    epochs = 50,
    imgsz = 640,
    batch = 16,
    degrees = 10,
    project = 'models/runs',
    name = 'yolov8n_neu_balanced',
    patience = 15,
)
# Out:
# Ultralytics 8.4.123 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from google.colab import files
best_weights = '/content/Real-Time-Industrial-Defect-Detection-System/runs/detect/models/runs/yolov8n_neu_balanced/weights/best.pt'
files.download(best_weights)
